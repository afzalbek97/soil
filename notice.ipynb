# %% [markdown]
# Frontend Development
#
# 1. BSSR (DTE/EJS)
# 2. SPA(ReactJS/AngularJS/VueJS)

# %% [markdown]
# API Design > Traditional API, Rest API or GraphQL API
# API Method > GET & POST
# API Structure > header & body

# %% [markdown]
# Validations:
# 1. Frontend Validation
# 2. DTO Validation
# 3. Backend Validation
# 4. Database Validation
